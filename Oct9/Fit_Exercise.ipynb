# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.load('fit_exercise.npy')

# %%
data
# Out:
# array([[ 0.59677897,  0.9210494 ,  1.15618395,  1.75451756,  1.8249173 ,
#          2.26851454,  2.28263231,  2.50455365,  2.86139335,  2.93714046,
#          3.12261223,  3.17285482,  3.22958914,  3.43178016,  3.61788656,
#          3.92117518,  3.98044255,  4.14826212,  4.2310646 ,  4.2583029 ,
#          4.26351307,  4.30862763,  4.33701173,  4.38572245,  4.80931901,
#          4.83034264,  4.93685098,  5.01836676,  5.19485119,  5.31551374,
#          5.31827587,  5.51314769,  6.11023511,  6.12894526,  6.23952952,
#          6.30976124,  6.34400959,  6.84829739,  6.96469186,  7.1946897 ,
#          7.22443383,  7.24455325,  7.29049707,  7.37995406,  8.49431794,
#          8.66309158,  8.93389163,  9.44160018,  9.80764198,  9.85559786],
#        [ 8.11257148,  3.52815075,  4.81023356,  0.89238164,  3.13295195,
#          3.53338034,  1.89933975,  2.83896349,  0.89713921,  0.9500022 ,
#          1.45700044,  1.05318568,  1.71011605,  0.06780647,  0.40019114,
# ...

# %%
plt.plot(data[0,:], data[1,:], 'o', label='Original data', markersize=2)
plt.title('Fit exercise')
plt.show()

# %%
len(data)
# Out:
# 3

# %%
var = np.vstack([data[0,:], np.ones(len(data[0,:]))]).T
#obtenemos los parámetros de la recta 
m, b = np.linalg.lstsq(var, data[1,:], rcond=None)[0]
print('La pendiente y la ordenada al origen son ', m, b)
# Out:
# La pendiente y la ordenada al origen son  -0.9821623517930427 4.57785930375336

# %%
plt.plot(data[0,:], data[1,:], 'o', label='Experimental data', markersize=2)
plt.plot(data[0,:], m*data[0,:] + b, 'b', label='Fit')
plt.title('Fit exercise')
plt.errorbar(data[0], data[1],yerr= data[2],ls='',label='Error')
plt.legend()
plt.show()

# %%
#El numero de datos se obtiene en la siguiente linea
n=len(data[0])
print('El número total de datos es:',n)

#calculamos la media del conjunto de datos llamadoo data
Xmean=np.mean(data[0])

#el cuadrado del número de datos es
cuadrado = data[0]*data[0]

#la suma del cuadrado del numero de datos es
x2_sum=cuadrado.sum()

#la suma multiplicar cada x_i con cada y_i
cuadrado2=data[0]*data[1]
XYsum=cuadrado2.sum()
Ymean=np.mean(data[1])

b2= ((Ymean* x2_sum)- (Xmean * XYsum) )/(x2_sum - (n*(Xmean)**2))
m2= (XYsum -n*Ymean*Xmean)/(x2_sum - n*(Xmean**2))

print('La pendiente y la ordenada al origen son ', m2, b2)
# Out:
# El número total de datos es: 50
# La pendiente y la ordenada al origen son  -0.9821623517930416 4.577859303753355

# %%
plt.plot(data[0], data[1], 'o', label='Experimental data', markersize=3)
plt.plot(data[0], m*data[0] + b, 'b', label='Fit')
plt.legend()
plt.title('Fit exercise')
plt.errorbar(data[0], data[1],yerr= data[2],ls='',label='Error')
plt.show()
